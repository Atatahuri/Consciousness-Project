# %%
Print("Hello New era!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Print("Hello New era!")
#
# NameError: name 'Print' is not defined

# %%
print("Hello new era")
# Out:
# Hello new era

# %%
x = 5
y = 3

z = x**2 + y**5
z
# Out:
# 268

# %%
def f(x):
    return x**2 - 3*x + 5

# %%
f(0)
# Out:
# 5

# %%
f(10)
# Out:
# 75

# %%
import math

# %%
def g(x,y):
    return x**2 *y + math.cos(x)

# %%
g(2,math.pi)
# Out:
# 12.15022377781203

# %%
def f(x):
    return 4 * x * (1 - x)

# %%
x = 0.1
for n in range(10):
    x = f(x)
    print(x)
# Out:
# 0.36000000000000004
# 0.9216
# 0.28901376000000006
# 0.8219392261226498
# 0.5854205387341974
# 0.970813326249438
# 0.11333924730376121
# 0.4019738492975123
# 0.9615634951138128
# 0.1478365599132853

# %%
def logistic(x,r):
    return r*x*(1-x)

# %%
x = 0.1
r = 3.9

    for n in range(10):
        x = logistic(x,r)
        print(n,x)
# Out:
#   Cell In[14], line 4
#     for n in range(10):
#     ^
# IndentationError: unexpected indent

# %%
for n in range(10):
    x = logistic(x,r)
    print(n,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 for n in range(10):
# ----> 2     x = logistic(x,r)
#       3     print(n,x)
#
# NameError: name 'r' is not defined

# %%
x = 0.1
r = 3.9 

for n in range(10):
    x = logistic(x,r)
    print(n,x)
# Out:
# 0 0.35100000000000003
# 1 0.8884161
# 2 0.3866184397170808
# 3 0.9248640249724619
# 4 0.2710131851083772
# 5 0.7705036505625796
# 6 0.6896283226260395
# 7 0.8347602871063352
# 8 0.5379486456882877
# 9 0.9693836111326567

# %%
r = 2

# %%
x = 0.1
r = 2

for n in range(20):
    x = logistic(x,r)
    print(n,x)
# Out:
# 0 0.18000000000000002
# 1 0.2952
# 2 0.41611392
# 3 0.4859262511644672
# 4 0.49960385918742867
# 5 0.49999968614491325
# 6 0.49999999999980305
# 7 0.5
# 8 0.5
# 9 0.5
# 10 0.5
# 11 0.5
# 12 0.5
# 13 0.5
# 14 0.5
# 15 0.5
# 16 0.5
# 17 0.5
# 18 0.5
# 19 0.5

# %%
def iterate(x,r,n):
    for i in range(n):
        x = logistic(x,r)
    return x

# %%
orbit(0.1,3,20)
# Out:
# 0.2700000000000001

# %%
orbit(0.1,3,20)
# Out:
# 0.6218970353408841

# %%
iterate(0.1,3,20)
# Out:
# 0.6218970353408841

# %%
def orbit(x,r,n):
    orbit_list = []

    for i in range(n):
        x = logistic(x,r)
        orbit_list.append(x)
    
    return orbit_list

# %%
orbit(0.1,2,20)
# Out:
# 0.18000000000000002
# 0.2952
# 0.41611392
# 0.4859262511644672
# 0.49960385918742867
# 0.49999968614491325
# 0.49999999999980305
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.