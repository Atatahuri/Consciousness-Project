# %%
def logistic(x,r):
    return r*x*(1- x)


def orbit(x,r): 
    orbit_list = []
    for i in range(1000): 
        orbit_list.append(x)
        x = logistic(x,r)
    return orbit_list[-100:]


tail = orbit(0.2,2.9)
print(tail)
# Out:
# [0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.6551724137931031, 0.6551724137931038, 0.655172413793103
# ...

# %%
print(orbit(0.2,3.2))
# Out:
# [0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.513044509532629
# ...

# %%
a = orbit(0.2,3.2)[0]
b = orbit(0.2,3.2)[1]


def derivative_logistic(x,r):
    return r*(1 - 2*x)

print(abs(derivative_logistic(a,3.2) * derivative_logistic(b,3.2)))
# Out:
# 0.15999999999999773

# %%
for r in [3.2,3.3,3.4,3.45,3.5]:
    print(r, orbit(0.2,r)[:10])
# Out:
# 3.2 [0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298, 0.7994554904673701, 0.5130445095326298]
# 3.3 [0.823603283206069, 0.4794270198242338, 0.8236032832060687, 0.4794270198242346, 0.8236032832060689, 0.47942701982423414, 0.823603283206069, 0.4794270198242338, 0.8236032832060687, 0.4794270198242346]
# 3.4 [0.8421543994326705, 0.4519632476261532, 0.8421543994326706, 0.451963247626153, 0.8421543994326705, 0.4519632476261532, 0.8421543994326706, 0.451963247626153, 0.8421543994326705, 0.4519632476261532]
# 3.45 [0.8474079359092888, 0.44611165493200394, 0.8524813596171226, 0.43386127437250327, 0.8474085579546792, 0.4461101638164836, 0.8524808051685926, 0.4338626228575673, 0.8474091733392829, 0.4461086886650205]
# ...

# %%
import numpy as np


r = np.linspace(3.45,3.5,11)

for i in r: 
    print(i, orbit(0.2,i)[:10])
# Out:
# 3.45 [np.float64(0.8474079359092888), np.float64(0.44611165493200394), np.float64(0.8524813596171226), np.float64(0.43386127437250327), np.float64(0.8474085579546792), np.float64(0.4461101638164836), np.float64(0.8524808051685926), np.float64(0.4338626228575673), np.float64(0.8474091733392829), np.float64(0.4461086886650205)]
# 3.455 [np.float64(0.8419195012589991), np.float64(0.4598295938461448), np.float64(0.8581747994118957), np.float64(0.4205108591438879), np.float64(0.841919501258982), np.float64(0.4598295938461852), np.float64(0.8581747994119069), np.float64(0.42051085914386016), np.float64(0.8419195012589668), np.float64(0.4598295938462212)]
# 3.46 [np.float64(0.8389518961100418), np.float64(0.4674861779469896), np.float64(0.8613422657592478), np.float64(0.41323391373686713), np.float64(0.8389518961100418), np.float64(0.4674861779469896), np.float64(0.8613422657592478), np.float64(0.41323391373686713), np.float64(0.8389518961100418), np.float64(0.4674861779469896)]
# ...

# %%
tail  = orbit(0.2,3.45)

for x in tail[:10]: 
    print(x)
# Out:
# 0.8474079359092888
# 0.44611165493200394
# 0.8524813596171226
# 0.43386127437250327
# 0.8474085579546792
# 0.4461101638164836
# 0.8524808051685926
# 0.4338626228575673
# 0.8474091733392829
# 0.4461086886650205

# %%
r = np.linspace(3.40,3.60,20)

for  i in r: 
    print(i, orbit(0.2,i)[:10])
# Out:
# 3.4 [np.float64(0.8421543994326705), np.float64(0.4519632476261532), np.float64(0.8421543994326706), np.float64(0.451963247626153), np.float64(0.8421543994326705), np.float64(0.4519632476261532), np.float64(0.8421543994326706), np.float64(0.451963247626153), np.float64(0.8421543994326705), np.float64(0.4519632476261532)]
# 3.4105263157894736 [np.float64(0.8438764211360361), np.float64(0.4493334554071745), np.float64(0.8438764211360371), np.float64(0.4493334554071721), np.float64(0.8438764211360361), np.float64(0.4493334554071745), np.float64(0.8438764211360371), np.float64(0.4493334554071721), np.float64(0.8438764211360361), np.float64(0.4493334554071745)]
# ...

# %%
for i in r: 
    tail = orbit(0.2,i)
    print(i, np.isclose(tail[0],tail[2]))
# Out:
# 3.4 True
# 3.4105263157894736 True
# 3.4210526315789473 True
# 3.431578947368421 True
# 3.442105263157895 True
# 3.4526315789473685 False
# 3.463157894736842 False
# 3.473684210526316 False
# 3.4842105263157896 False
# 3.4947368421052634 False
# 3.5052631578947366 False
# 3.5157894736842104 False
# 3.526315789473684 False
# 3.536842105263158 False
# 3.5473684210526315 False
# 3.557894736842105 False
# 3.568421052631579 False
# 3.5789473684210527 False
# 3.5894736842105264 False
# 3.6 False

# %%
def detect_peroid(tail): 
    # if np.isclose(tail[0],tail[1]) == True:
    #     return 1
    # if np.isclose(tail[0],tail[2]) == True:
    #     return 2
    # if np.isclose(tail[0],tail[4]) == True:
    #     return 4
    # if np.isclose(tail[0],tail[8]) == True:
    #     return 8
    for k in range(10): 
        p  = 2 ** k
        if(np.isclose(tail[0], tail[p])):
            return p



print(detect_peroid(orbit(0.2, 3.4)))
print(detect_peroid(orbit(0.2, 3.5)))
print(detect_peroid(orbit(0.2, 3.9)))
# Out:
# 2
# 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 19
#      15
#      16
#      17 print(detect_peroid(orbit(0.2, 3.4)))
#      18 print(detect_peroid(orbit(0.2, 3.5)))
# ---> 19 print(detect_peroid(orbit(0.2, 3.9)))
#      20
#
# Cell In[19], line 12, in detect_peroid(tail)
#       8     # if np.isclose(tail[0],tail[8]) == True:
#       9     #     return 8
#      10     for k in range(10):
#      11         p  = 2 ** k
# ---> 12         if(np.isclose(tail[0], tail[p])):
#      13             return p
#
# IndexError: list index out of range

# %%
for r in np.linspace(3.0, 3.6, 25):
    tail = orbit(0.2, r)
    print(r, detect_peroid(tail))
# Out:
# 3.0 None
# 3.025 2
# 3.05 2
# 3.075 2
# 3.1 2
# 3.125 2
# 3.15 2
# 3.175 2
# 3.2 2
# 3.225 2
# 3.25 2
# 3.275 2
# 3.3 2
# 3.325 2
# 3.35 2
# 3.375 2
# 3.4 2
# 3.4250000000000003 2
# 3.45 4
# 3.475 4
# 3.5 4
# 3.5250000000000004 4
# 3.5500000000000003 8
# 3.575 None
# 3.6 None

# %%
a = 3.44
b = 3.45

m = (a + b)/2

detect_peroid(orbit(0.2,m))
# Out:
# 2

# %%
a = 3.44
b = 3.45

for i in range(20):
    m = (a +b)/2
    if detect_peroid(orbit(0.2,m)) == 2: 
        a = m
    if detect_peroid(orbit(0.2,m)) == 4: 
        b = m
print(a,b)
print(m)
# Out:
# 3.4465694522857664 3.44656946182251
# 3.4465694522857664

# %%
r = 3.44657

tail = orbit(0.2, r)

print(tail[0])
print(tail[2])
print(tail[0] - tail[2])
print(np.isclose(tail[0], tail[2]))
# Out:
# 0.8494954126634863
# 0.8495039279041233
# -8.515240637052557e-06
# False

# %%
long_tail = []
def long_orbit(x,r):
    for i in range(10000):
        x = logistic(x,r)
        long_tail.append(x)
    return long_tail[-100:]

print(long_orbit(0.2, 3.445))
r = 3.44657

print(long_orbit(0.2,r)[0] - long_orbit(0.2,r)[2])
# Out:
# [0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126607888131, 0.849263101185042, 0.4410126607888415, 0.8492631011850538, 0.4410126
# ...

# %%
a = 3.44
b = 3.45

for i in range(20):
    m = (a +b)/2
    if detect_peroid(long_orbit(0.2,m)) == 2: 
        a = m
    if detect_peroid(long_orbit(0.2,m)) == 4: 
        b = m
print(a,b)
print(m)
# Out:
# 3.4491805839538574 3.449180593490601
# 3.449180593490601

# %%
r = 3.5

def derivative_logistic(x,r):
    return r*(1 - 2*x)

tail = long_orbit(0.2,r)
a = derivative_logistic(tail[0],r) * derivative_logistic(tail[1],r) * derivative_logistic(tail[2],r) * derivative_logistic(tail[3],r)

print(a)
# Out:
# -0.0304999759736618

# %%
def cocycle(x,r,p):
    multiplier = 1
    tail = long_orbit(x,r)
    for i in range(p):
        multiplier = multiplier * derivative_logistic(tail[i],r)
    return multiplier

print(cocycle(0.2,3.5,4))
# Out:
# -0.0304999759736618

# %%
for r in np.linspace(3.50, 3.55, 11):
    print(r, cocycle(0.2, r, 4))
# Out:
# 3.5 -0.0304999759736618
# 3.505 -0.1370706223459703
# 3.51 -0.2444894040782522
# 3.515 -0.35276290161687723
# 3.52 -0.461897708861622
# 3.525 -0.5719004331088569
# 3.53 -0.6827776949963177
# 3.5349999999999997 -0.794536128449974
# 3.54 -0.9071823806318079
# 3.545 -1.2664117188683628
# 3.55 -1.668756330059036

# %%
a = 3.54
b = 3.545

for i in range(20):
    m = (a +b)/2
    if cocycle(0.2,m,4) > -1: 
        a = m
    else: 
        b = m
print(a,b)
print(m)
# Out:
# 3.544022507667542 3.5440225124359133
# 3.544022507667542

# %%
r1 = 3
r2 = 1 + np.sqrt(6)
r3 = 3.544022507667542

print((r2-r1)/(r3-r2))
# Out:
# 4.754856618580986

# %%
for r in np.linspace(3.55, 3.565, 7):
    print(r, cocycle(0.2, r, 8))
# Out:
# 3.55 0.4497165923050867
# 3.5524999999999998 0.20942694990160474
# 3.5549999999999997 -0.035467343126060605
# 3.5575 -0.28506771405486686
# 3.56 -0.5394763657639897
# 3.5625 -0.7987962787365991
# 3.565 -1.5339456893028238

# %%
a = 3.5625
b = 3.565

for i in range(20):
    m = (a+b)/2
    if cocycle(0.2,m,8) > -1:
        a = m
    else:
        b = m

print(m)
r4 = m
print((r3 - r2)/(r4-r3))
# Out:
# 3.564379813671112
# 4.643677550840223

# %%
import matplotlib.pyplot as plt
import numpy as np

def logistic_solution(x0, t, M):
    return (M*x0) / ((M-x0)*np.exp(-4*t) + x0)

taxis = np.linspace(-5, 5, 2000)
initial = np.linspace(-4, 10, 20)

for x0 in initial:
    y = logistic_solution(x0, taxis, 4)
    plt.plot(taxis, y)

plt.axhline(0, linestyle="--")
plt.axhline(4, linestyle="--")
plt.xlabel("t")
plt.ylabel("x(t)")
plt.ylim(-10, 10)
plt.show()

# %%
for x0 in initial:
    y = logistic_solution(x0, taxis, 4)

    y[np.abs(y) > 20] = np.nan

    plt.plot(taxis, y)

plt.axhline(0, linestyle="--")
plt.axhline(4, linestyle="--")
plt.ylim(-10, 10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



taxis = np.linspace(-5, 5, 20)
xaxis = np.linspace(-0.5, 1.5,20)

for x in xaxis:
    for t in taxis:
        plt.quiver(t,x,1,5*x*(1 - x)*(x - 0.3),angles = "xy")

plt.axhline(0, linestyle="--")
plt.axhline(0.3, linestyle="--")
plt.axhline(1, linestyle="--")
plt.xlabel("t")
plt.ylabel("x(t)")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



taxis = np.linspace(-5, 5, 20)
xaxis = np.linspace(-2, 16,20)

for x in xaxis:
    for t in taxis:
        plt.quiver(t,x,1,x*(13 - x) - 12,angles = "xy")

plt.axhline(1, linestyle="--")
plt.axhline(12, linestyle="--")
plt.axhline(1, linestyle="--")
plt.xlabel("t")
plt.ylabel("x(t)")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



taxis = np.linspace(-5, 5, 20)
xaxis = np.linspace(-3, 3,20)

for x in xaxis:
    for t in taxis:
        plt.quiver(t,x,1,(x**2)*(x**2 - 4),angles = "xy")

plt.axhline(0, linestyle="--")
plt.axhline(2, linestyle="--")
plt.axhline(-2, linestyle="--")
plt.xlabel("t")
plt.ylabel("x(t)")

plt.show()
